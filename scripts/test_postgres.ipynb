# %%
# !pip install psycopg2-binary python-dotenv
# Out:
# Requirement already satisfied: psycopg2-binary in c:\users\yusuf\anaconda3\envs\kaim_week7\lib\site-packages (2.9.10)
# Requirement already satisfied: python-dotenv in c:\users\yusuf\appdata\roaming\python\python39\site-packages (1.1.0)

# %%
import psycopg2
from dotenv import load_dotenv
import os

load_dotenv()

conn = psycopg2.connect(
    dbname=os.getenv("POSTGRES_DB"),
    user=os.getenv("POSTGRES_USER"),
    password=os.getenv("POSTGRES_PASSWORD"),
    host=os.getenv("POSTGRES_HOST"),
    port=os.getenv("POSTGRES_PORT")
)

cur = conn.cursor()
cur.execute("SELECT version();")
print(cur.fetchone())
cur.close()
conn.close()
# Out:
# ('PostgreSQL 13.21 (Debian 13.21-1.pgdg120+1) on x86_64-pc-linux-gnu, compiled by gcc (Debian 12.2.0-14) 12.2.0, 64-bit',)
